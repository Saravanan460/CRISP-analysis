# %%
import pandas as pd

# Load the data
df = pd.read_csv(r'data sets\2019Floor7.csv')

# Check for missing values
print(df.isnull().sum())

# Check time format
print(df.columns[0])  # usually the timestamp column
print(df[df.columns[0]].head())

# Convert timestamp if needed
df['Timestamp'] = pd.to_datetime(df[df.columns[0]])
df.set_index('Timestamp', inplace=True)
# Out:
# Date                 0
# z1_AC1(kW)        4413
# z1_AC2(kW)        4413
# z1_AC3(kW)        4413
# z1_AC4(kW)       29788
# z1_Light(kW)      2544
# z1_Plug(kW)        777
# z1_S1(degC)     101499
# z1_S1(RH%)      101497
# z1_S1(lux)      101497
# z2_AC1(kW)       29793
# z2_Light(kW)      2544
# z2_Plug(kW)       2892
# z2_S1(degC)     100896
# z2_S1(RH%)      100897
# z2_S1(lux)      100900
# z3_Light(kW)      1764
# z3_Plug(kW)       3232
# z4_AC1(kW)       29775
# z4_Light(kW)      7423
# z4_Plug(kW)       4413
# z4_S1(degC)     109355
# z4_S1(RH%)      109356
# z4_S1(lux)      109359
# z5_AC1(kW)       29769
# z5_Light(kW)      4090
# z5_Plug(kW)       4413
# z5_S1(degC)     117899
# z5_S1(RH%)      117899
# z5_S1(lux)      117900
# dtype: int64
# Date
# 0    2019-01-01 00:00:00
# 1    2019-01-01 00:01:00
# 2    2019-01-01 00:02:00
# 3    2019-01-01 00:03:00
# 4    2019-01-01 00:04:00
# Name: Date, dtype: object

# %%
import matplotlib.pyplot as plt

df['z2_AC1(kW)'].plot(figsize=(15, 5), title='Zone 2 AC Unit 1 Usage (kW)')
plt.ylabel('Power (kW)')
plt.show()
df['z1_S1(degC)'].plot(figsize=(15, 5), title='Zone 1 temp')
plt.ylabel('temp (degC)')
plt.show()
df['z2_S1(degC)'].plot(figsize=(15, 5), title='Zone 2 temp')
plt.ylabel('temp (degC)')
plt.show()
df['z4_S1(degC)'].plot(figsize=(15, 5), title='Zone 4 temp')
plt.ylabel('temp (degC)')
plt.show()
df['z5_S1(degC)'].plot(figsize=(15, 5), title='Zone 5 temp')
plt.ylabel('temp (degC)')
plt.show()
